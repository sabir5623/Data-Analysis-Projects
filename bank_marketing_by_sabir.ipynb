# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Pc/Downloads/bank_marketing (1).csv")
df
# Out:
#       Unnamed: 0  age          job  marital  education default  balance  \
# 0              0   41     services  married    unknown      no       88
# 1              1   56   technician  married  secondary      no     1938
# 2              2   30     services   single  secondary      no      245
# 3              3   34   management   single   tertiary      no     1396
# 4              4   29   technician   single  secondary      no      -13
# ...          ...  ...          ...      ...        ...     ...      ...
# 5576        5576   48       admin.  married  secondary      no     2235
# 5577        5577   40  blue-collar  married    primary      no     -388
# 5578        5578   27      student   single  secondary      no       91
# 5579        5579   46  blue-collar  married  secondary      no     1568
# 5580        5580   39     services  married  secondary      no        0
#
#      housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
#1. Drop unnamed: 0 column from the dataset.

# %%
df1=df.drop(["Unnamed: 0"],axis=1)
df1
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      41     services  married    unknown      no       88     yes   no
# 1      56   technician  married  secondary      no     1938      no  yes
# 2      30     services   single  secondary      no      245      no  yes
# 3      34   management   single   tertiary      no     1396     yes   no
# 4      29   technician   single  secondary      no      -13     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 5576   48       admin.  married  secondary      no     2235     yes  yes
# 5577   40  blue-collar  married    primary      no     -388     yes   no
# 5578   27      student   single  secondary      no       91      no   no
# 5579   46  blue-collar  married  secondary      no     1568     yes   no
# 5580   39     services  married  secondary      no        0     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
#2. Count the the number of people in different job profiles.

# %%
df1["job"].value_counts()
# Out:
# management       1318
# blue-collar       975
# technician        887
# admin.            661
# services          452
# retired           397
# self-employed     206
# student           182
# unemployed        170
# entrepreneur      160
# housemaid         143
# unknown            30
# Name: job, dtype: int64

# %%
#3. How many people are doing service?

# %%
df1["job"].value_counts().services
# Out:
# 452

# %%
#4. Find the number of people having minus balance in their account.

# %%
df1[df1["balance"]<0].value_counts().sum()
# Out:
# 348

# %%
#5. Find the number of people deposit money to their bank who are from management profile.

# %%
df[(df["job"]=="management")&(df["deposit"]=="yes")].value_counts().sum()
# Out:
# 669

# %%
#6. Find the percentage of each contact method among the group of people.

# %%
df1["contact"].value_counts(normalize=True)*100
# Out:
# cellular     72.460133
# unknown      20.695216
# telephone     6.844651
# Name: contact, dtype: float64

# %%
#7. Find the number of unmarried students who don’t deposit money to their bank.

# %%
df[(df["job"]=="student")&(df["marital"]=="single")&(df["deposit"]=="no")].value_counts().shape[0]
# Out:
# 49

# %%
#8. Find the number of calls through unknown contact method in the month of may.

# %%
df[(df["contact"]=="unknown")&(df["month"]=="may")].shape[0]
# Out:
# 686

# %%
#9. Find the number of unemployed married people who have taken loan.

# %%
df[(df["job"]=="unemployed")&(df["marital"]=="married")&(df["loan"]=="yes")].shape[0]
# Out:
# 8

# %%
#10. Find the top five largest amount of balance in the accounts of the people.

# %%
df["balance"].nlargest()
# Out:
# 507     81204
# 3252    81204
# 1115    56831
# 3527    51439
# 4357    37127
# Name: balance, dtype: int64
